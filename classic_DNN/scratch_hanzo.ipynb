# %%
import constants
import yfinance as yf

# Get symbols from constants file
lines = constants.sa_str.splitlines()
symbols = [line.split("\t")[1] for line in lines][:100]

# Download data
df = yf.download(symbols + ["SPY"], period="1y", interval="1h", ignore_tz=True)

# %%
import data_pipes

hanzo_data = data_pipes.hanzo_df_array(symbols, df)
hanzo_data['y'].std()

# %%
import torch
from torch import nn, optim

class hanzo_0(nn.Module):
    def __init__(self, hist):
        super().__init__()
        self.flat0 = nn.Flatten()
        self.hidden0 = nn.Linear(hist*2, hist)
        self.act0 = nn.Tanh()
        self.hidden1 = nn.Linear(hist, hist)
        self.act1 = nn.Tanh()
        self.hidden2 = nn.Linear(hist, 1)
        self.act2 = nn.Tanh()
 
    def forward(self, x):
        x = self.flat0(x)
        x = self.act0(self.hidden0(x))
        x = self.act1(self.hidden1(x))
        x = self.act2(self.hidden2(x))
        return x
    

class hanzo_1(nn.Module):
    def __init__(self, hist, dropout_rate=0.3):
        super().__init__()
        self.flat0 = nn.Flatten(start_dim=1)
        self.hidden0 = nn.Linear(hist * 2, hist)
        self.act0 = nn.ReLU()
        self.dropout0 = nn.Dropout(dropout_rate)
        
        self.hidden1 = nn.Linear(hist, hist)
        self.act1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout_rate)

        self.hidden2 = nn.Linear(hist, 1)
        self.act2 = nn.Tanh()  # Keeping tanh for the output since it's likely regression

    def forward(self, x):
        x = self.flat0(x)
        x = self.dropout0(self.act0(self.hidden0(x)))
        x = self.dropout1(self.act1(self.hidden1(x)))
        x = self.act2(self.hidden2(x))
        return x

# %%
import numpy as np
import torch_ops as ops
from copy import deepcopy

hist = 10
epochs, batch_size, lr, l2_decay = 200, 32, 3e-4, 1e-5
model = hanzo_1(hist=hist)
loss_fn = nn.L1Loss()
optimizer = optim.Adam(params=model.parameters(), lr=lr, weight_decay=l2_decay)

period = 10
x = torch.tensor(hanzo_data["x"], dtype=torch.float32)
y = torch.tensor(hanzo_data["y"], dtype=torch.float32)

# %%
t = period
# for t in range(period, len(x)):
x_t = x[t - period:t]
x_v = x[t - 1:t]
x_t_flat = torch.concatenate([x_t[:, i] for i in range(x_t.shape[1])])
x_v_flat = torch.concatenate([x_v[:, i] for i in range(x_v.shape[1])])

y_t = y[t - period:t]
y_v = y[t - 1:t]
y_t_flat = torch.concatenate([y_t[:, i] for i in range(y_t.shape[1])])
y_v_flat = torch.concatenate([y_v[:, i] for i in range(y_v.shape[1])])

test_loss = 999
for epoch in range(epochs):
    loss = ops.train_loop(x_t_flat, y_t_flat, model, loss_fn, optimizer, batch_size)
    test_loss_new = ops.test_loop(x_v_flat, y_v_flat, model, loss_fn, batch_size)

    if test_loss_new < test_loss or epoch == epochs - 1:
        print(f"---------- Epoch {epoch + 1} ----------")
        print(f"loss: {loss:1.4f}, test loss: {test_loss_new:1.4f}")
        
    if test_loss_new < test_loss:
        test_loss = test_loss_new
        print(f"Checkpoint: test loss = {test_loss:1.4f} <---------------")
        state_dict_save = deepcopy(model.state_dict())
        torch.save(model.state_dict(), r"models/hanzo_0")
# Out:
# ---------- Epoch 1 ----------
# loss: 0.2324, test loss: 0.4335
# Checkpoint: test loss = 0.4335 <---------------
# ---------- Epoch 2 ----------
# loss: 0.2325, test loss: 0.4333
# Checkpoint: test loss = 0.4333 <---------------
# ---------- Epoch 3 ----------
# loss: 0.2443, test loss: 0.4331
# Checkpoint: test loss = 0.4331 <---------------
# ---------- Epoch 4 ----------
# loss: 0.2311, test loss: 0.4330
# Checkpoint: test loss = 0.4330 <---------------
# ---------- Epoch 5 ----------
# loss: 0.2307, test loss: 0.4328
# Checkpoint: test loss = 0.4328 <---------------
# ---------- Epoch 6 ----------
# loss: 0.2406, test loss: 0.4326
# Checkpoint: test loss = 0.4326 <---------------
# ---------- Epoch 7 ----------
# loss: 0.2282, test loss: 0.4324
# Checkpoint: test loss = 0.4324 <---------------
# ---------- Epoch 8 ----------
# loss: 0.2328, test loss: 0.4323
# Checkpoint: test loss = 0.4323 <---------------
# ---------- Epoch 9 ----------
# loss: 0.2274, test loss: 0.4321
# Checkpoint: test loss = 0.4321 <---------------
# ---------- Epoch 10 ----------
# loss: 0.2375, test loss: 0.4319
# Checkpoint: test loss = 0.4319 <---------------
# ---------- Epoch 11 ----------
# loss: 0.2354, test loss: 0.4317
# Checkpoint: test loss = 0.4317 <---------------
# ---------- Epoch 12 ----------
# loss: 0.2323, test loss: 0.4315
# Checkpoint: test loss = 0.4315 <---------------
# ---------- Epoch 13 ----------
# loss: 0.2343, test loss: 0.4313
# Checkpoint: test loss = 0.4313 <---------------
# ---------- Epoch 14 ----------
# loss: 0.2316, test loss: 0.4312
# Checkpoint: test loss = 0.4312 <---------------
# ---------- Epoch 15 ----------
# loss: 0.2272, test loss: 0.4310
# Checkpoint: test loss = 0.4310 <---------------
# ---------- Epoch 16 ----------
# loss: 0.2357, test loss: 0.4308
# Checkpoint: test loss = 0.4308 <---------------
# ---------- Epoch 17 ----------
# loss: 0.2353, test loss: 0.4306
# Checkpoint: test loss = 0.4306 <---------------
# ---------- Epoch 18 ----------
# loss: 0.2277, test loss: 0.4304
# Checkpoint: test loss = 0.4304 <---------------
# ---------- Epoch 19 ----------
# loss: 0.2268, test loss: 0.4302
# Checkpoint: test loss = 0.4302 <---------------
# ---------- Epoch 20 ----------
# loss: 0.2369, test loss: 0.4300
# Checkpoint: test loss = 0.4300 <---------------
# ---------- Epoch 21 ----------
# loss: 0.2343, test loss: 0.4299
# Checkpoint: test loss = 0.4299 <---------------
# ---------- Epoch 22 ----------
# loss: 0.2231, test loss: 0.4297
# Checkpoint: test loss = 0.4297 <---------------
# ---------- Epoch 23 ----------
# loss: 0.2305, test loss: 0.4295
# Checkpoint: test loss = 0.4295 <---------------
# ---------- Epoch 24 ----------
# loss: 0.2254, test loss: 0.4293
# Checkpoint: test loss = 0.4293 <---------------
# ---------- Epoch 25 ----------
# loss: 0.2346, test loss: 0.4291
# Checkpoint: test loss = 0.4291 <---------------
# ---------- Epoch 26 ----------
# loss: 0.2323, test loss: 0.4289
# Checkpoint: test loss = 0.4289 <---------------
# ---------- Epoch 27 ----------
# loss: 0.2282, test loss: 0.4288
# Checkpoint: test loss = 0.4288 <---------------
# ---------- Epoch 28 ----------
# loss: 0.2244, test loss: 0.4286
# Checkpoint: test loss = 0.4286 <---------------
# ---------- Epoch 29 ----------
# loss: 0.2303, test loss: 0.4284
# Checkpoint: test loss = 0.4284 <---------------
# ---------- Epoch 30 ----------
# loss: 0.2235, test loss: 0.4282
# Checkpoint: test loss = 0.4282 <---------------
# ---------- Epoch 31 ----------
# loss: 0.2227, test loss: 0.4280
# Checkpoint: test loss = 0.4280 <---------------
# ---------- Epoch 32 ----------
# loss: 0.2313, test loss: 0.4278
# Checkpoint: test loss = 0.4278 <---------------
# ---------- Epoch 33 ----------
# loss: 0.2304, test loss: 0.4277
# Checkpoint: test loss = 0.4277 <---------------
# ---------- Epoch 34 ----------
# loss: 0.2262, test loss: 0.4275
# Checkpoint: test loss = 0.4275 <---------------
# ---------- Epoch 35 ----------
# loss: 0.2260, test loss: 0.4273
# Checkpoint: test loss = 0.4273 <---------------
# ---------- Epoch 36 ----------
# loss: 0.2281, test loss: 0.4271
# Checkpoint: test loss = 0.4271 <---------------
# ---------- Epoch 37 ----------
# loss: 0.2328, test loss: 0.4269
# Checkpoint: test loss = 0.4269 <---------------
# ---------- Epoch 38 ----------
# loss: 0.2229, test loss: 0.4267
# Checkpoint: test loss = 0.4267 <---------------
# ---------- Epoch 39 ----------
# loss: 0.2272, test loss: 0.4266
# Checkpoint: test loss = 0.4266 <---------------
# ---------- Epoch 40 ----------
# loss: 0.2278, test loss: 0.4264
# Checkpoint: test loss = 0.4264 <---------------
# ---------- Epoch 41 ----------
# loss: 0.2283, test loss: 0.4262
# Checkpoint: test loss = 0.4262 <---------------
# ---------- Epoch 42 ----------
# loss: 0.2280, test loss: 0.4260
# Checkpoint: test loss = 0.4260 <---------------
# ---------- Epoch 43 ----------
# loss: 0.2210, test loss: 0.4258
# Checkpoint: test loss = 0.4258 <---------------
# ---------- Epoch 44 ----------
# loss: 0.2311, test loss: 0.4256
# Checkpoint: test loss = 0.4256 <---------------
# ---------- Epoch 45 ----------
# loss: 0.2151, test loss: 0.4254
# Checkpoint: test loss = 0.4254 <---------------
# ---------- Epoch 46 ----------
# loss: 0.2253, test loss: 0.4253
# Checkpoint: test loss = 0.4253 <---------------
# ---------- Epoch 47 ----------
# loss: 0.2233, test loss: 0.4251
# Checkpoint: test loss = 0.4251 <---------------
# ---------- Epoch 48 ----------
# loss: 0.2196, test loss: 0.4249
# Checkpoint: test loss = 0.4249 <---------------
# ---------- Epoch 49 ----------
# loss: 0.2127, test loss: 0.4247
# Checkpoint: test loss = 0.4247 <---------------
# ---------- Epoch 50 ----------
# loss: 0.2242, test loss: 0.4245
# Checkpoint: test loss = 0.4245 <---------------
# ---------- Epoch 51 ----------
# loss: 0.2270, test loss: 0.4243
# Checkpoint: test loss = 0.4243 <---------------
# ---------- Epoch 52 ----------
# loss: 0.2251, test loss: 0.4241
# Checkpoint: test loss = 0.4241 <---------------
# ---------- Epoch 53 ----------
# loss: 0.2216, test loss: 0.4240
# Checkpoint: test loss = 0.4240 <---------------
# ---------- Epoch 54 ----------
# loss: 0.2250, test loss: 0.4238
# Checkpoint: test loss = 0.4238 <---------------
# ---------- Epoch 55 ----------
# loss: 0.2223, test loss: 0.4236
# Checkpoint: test loss = 0.4236 <---------------
# ---------- Epoch 56 ----------
# loss: 0.2266, test loss: 0.4234
# Checkpoint: test loss = 0.4234 <---------------
# ---------- Epoch 57 ----------
# loss: 0.2288, test loss: 0.4232
# Checkpoint: test loss = 0.4232 <---------------
# ---------- Epoch 58 ----------
# loss: 0.2253, test loss: 0.4230
# Checkpoint: test loss = 0.4230 <---------------
# ---------- Epoch 59 ----------
# loss: 0.2272, test loss: 0.4228
# Checkpoint: test loss = 0.4228 <---------------
# ---------- Epoch 60 ----------
# loss: 0.2225, test loss: 0.4226
# Checkpoint: test loss = 0.4226 <---------------
# ---------- Epoch 61 ----------
# loss: 0.2198, test loss: 0.4225
# Checkpoint: test loss = 0.4225 <---------------
# ---------- Epoch 62 ----------
# loss: 0.2154, test loss: 0.4223
# Checkpoint: test loss = 0.4223 <---------------
# ---------- Epoch 63 ----------
# loss: 0.2177, test loss: 0.4221
# Checkpoint: test loss = 0.4221 <---------------
# ---------- Epoch 64 ----------
# loss: 0.2159, test loss: 0.4219
# Checkpoint: test loss = 0.4219 <---------------
# ---------- Epoch 65 ----------
# loss: 0.2186, test loss: 0.4217
# Checkpoint: test loss = 0.4217 <---------------
# ---------- Epoch 66 ----------
# loss: 0.2191, test loss: 0.4215
# Checkpoint: test loss = 0.4215 <---------------
# ---------- Epoch 67 ----------
# loss: 0.2208, test loss: 0.4213
# Checkpoint: test loss = 0.4213 <---------------
# ---------- Epoch 68 ----------
# loss: 0.2228, test loss: 0.4211
# Checkpoint: test loss = 0.4211 <---------------
# ---------- Epoch 69 ----------
# loss: 0.2173, test loss: 0.4209
# Checkpoint: test loss = 0.4209 <---------------
# ---------- Epoch 70 ----------
# loss: 0.2201, test loss: 0.4207
# Checkpoint: test loss = 0.4207 <---------------
# ---------- Epoch 71 ----------
# loss: 0.2198, test loss: 0.4205
# Checkpoint: test loss = 0.4205 <---------------
# ---------- Epoch 72 ----------
# loss: 0.2214, test loss: 0.4204
# Checkpoint: test loss = 0.4204 <---------------
# ---------- Epoch 73 ----------
# loss: 0.2095, test loss: 0.4202
# Checkpoint: test loss = 0.4202 <---------------
# ---------- Epoch 74 ----------
# loss: 0.2188, test loss: 0.4200
# Checkpoint: test loss = 0.4200 <---------------
# ---------- Epoch 75 ----------
# loss: 0.2214, test loss: 0.4198
# Checkpoint: test loss = 0.4198 <---------------
# ---------- Epoch 76 ----------
# loss: 0.2104, test loss: 0.4196
# Checkpoint: test loss = 0.4196 <---------------
# ---------- Epoch 77 ----------
# loss: 0.2137, test loss: 0.4194
# Checkpoint: test loss = 0.4194 <---------------
# ---------- Epoch 78 ----------
# loss: 0.2198, test loss: 0.4192
# Checkpoint: test loss = 0.4192 <---------------
# ---------- Epoch 79 ----------
# loss: 0.2165, test loss: 0.4190
# Checkpoint: test loss = 0.4190 <---------------
# ---------- Epoch 80 ----------
# loss: 0.2168, test loss: 0.4188
# Checkpoint: test loss = 0.4188 <---------------
# ---------- Epoch 81 ----------
# loss: 0.2185, test loss: 0.4186
# Checkpoint: test loss = 0.4186 <---------------
# ---------- Epoch 82 ----------
# loss: 0.2199, test loss: 0.4184
# Checkpoint: test loss = 0.4184 <---------------
# ---------- Epoch 83 ----------
# loss: 0.2240, test loss: 0.4182
# Checkpoint: test loss = 0.4182 <---------------
# ---------- Epoch 84 ----------
# loss: 0.2177, test loss: 0.4180
# Checkpoint: test loss = 0.4180 <---------------
# ---------- Epoch 85 ----------
# loss: 0.2147, test loss: 0.4178
# Checkpoint: test loss = 0.4178 <---------------
# ---------- Epoch 86 ----------
# loss: 0.2124, test loss: 0.4176
# Checkpoint: test loss = 0.4176 <---------------
# ---------- Epoch 87 ----------
# loss: 0.2098, test loss: 0.4174
# Checkpoint: test loss = 0.4174 <---------------
# ---------- Epoch 88 ----------
# loss: 0.2129, test loss: 0.4172
# Checkpoint: test loss = 0.4172 <---------------
# ---------- Epoch 89 ----------
# loss: 0.2083, test loss: 0.4170
# Checkpoint: test loss = 0.4170 <---------------
# ---------- Epoch 90 ----------
# loss: 0.2082, test loss: 0.4168
# Checkpoint: test loss = 0.4168 <---------------
# ---------- Epoch 91 ----------
# loss: 0.2104, test loss: 0.4166
# Checkpoint: test loss = 0.4166 <---------------
# ---------- Epoch 92 ----------
# loss: 0.2155, test loss: 0.4164
# Checkpoint: test loss = 0.4164 <---------------
# ---------- Epoch 93 ----------
# loss: 0.2118, test loss: 0.4162
# Checkpoint: test loss = 0.4162 <---------------
# ---------- Epoch 94 ----------
# loss: 0.2184, test loss: 0.4160
# Checkpoint: test loss = 0.4160 <---------------
# ---------- Epoch 95 ----------
# loss: 0.2181, test loss: 0.4158
# Checkpoint: test loss = 0.4158 <---------------
# ---------- Epoch 96 ----------
# loss: 0.2137, test loss: 0.4156
# Checkpoint: test loss = 0.4156 <---------------
# ---------- Epoch 97 ----------
# loss: 0.2123, test loss: 0.4154
# Checkpoint: test loss = 0.4154 <---------------
# ---------- Epoch 98 ----------
# loss: 0.2119, test loss: 0.4152
# Checkpoint: test loss = 0.4152 <---------------
# ---------- Epoch 99 ----------
# loss: 0.2137, test loss: 0.4150
# Checkpoint: test loss = 0.4150 <---------------
# ---------- Epoch 100 ----------
# loss: 0.2131, test loss: 0.4148
# Checkpoint: test loss = 0.4148 <---------------
# ---------- Epoch 101 ----------
# loss: 0.2055, test loss: 0.4146
# Checkpoint: test loss = 0.4146 <---------------
# ---------- Epoch 102 ----------
# loss: 0.2088, test loss: 0.4144
# Checkpoint: test loss = 0.4144 <---------------
# ---------- Epoch 103 ----------
# loss: 0.2054, test loss: 0.4142
# Checkpoint: test loss = 0.4142 <---------------
# ---------- Epoch 104 ----------
# loss: 0.2093, test loss: 0.4140
# Checkpoint: test loss = 0.4140 <---------------
# ---------- Epoch 105 ----------
# loss: 0.2084, test loss: 0.4138
# Checkpoint: test loss = 0.4138 <---------------
# ---------- Epoch 106 ----------
# loss: 0.2089, test loss: 0.4136
# Checkpoint: test loss = 0.4136 <---------------
# ---------- Epoch 107 ----------
# loss: 0.2029, test loss: 0.4134
# Checkpoint: test loss = 0.4134 <---------------
# ---------- Epoch 108 ----------
# loss: 0.2089, test loss: 0.4132
# Checkpoint: test loss = 0.4132 <---------------
# ---------- Epoch 109 ----------
# loss: 0.2105, test loss: 0.4130
# Checkpoint: test loss = 0.4130 <---------------
# ---------- Epoch 110 ----------
# loss: 0.2101, test loss: 0.4128
# Checkpoint: test loss = 0.4128 <---------------
# ---------- Epoch 111 ----------
# loss: 0.2024, test loss: 0.4126
# Checkpoint: test loss = 0.4126 <---------------
# ---------- Epoch 112 ----------
# loss: 0.2056, test loss: 0.4124
# Checkpoint: test loss = 0.4124 <---------------
# ---------- Epoch 113 ----------
# loss: 0.2123, test loss: 0.4122
# Checkpoint: test loss = 0.4122 <---------------
# ---------- Epoch 114 ----------
# loss: 0.2115, test loss: 0.4120
# Checkpoint: test loss = 0.4120 <---------------
# ---------- Epoch 115 ----------
# loss: 0.2030, test loss: 0.4118
# Checkpoint: test loss = 0.4118 <---------------
# ---------- Epoch 116 ----------
# loss: 0.2043, test loss: 0.4116
# Checkpoint: test loss = 0.4116 <---------------
# ---------- Epoch 117 ----------
# loss: 0.2067, test loss: 0.4114
# Checkpoint: test loss = 0.4114 <---------------
# ---------- Epoch 118 ----------
# loss: 0.2080, test loss: 0.4112
# Checkpoint: test loss = 0.4112 <---------------
# ---------- Epoch 119 ----------
# loss: 0.2090, test loss: 0.4110
# Checkpoint: test loss = 0.4110 <---------------
# ---------- Epoch 120 ----------
# loss: 0.2065, test loss: 0.4108
# Checkpoint: test loss = 0.4108 <---------------
# ---------- Epoch 121 ----------
# loss: 0.2048, test loss: 0.4106
# Checkpoint: test loss = 0.4106 <---------------
# ---------- Epoch 122 ----------
# loss: 0.2053, test loss: 0.4104
# Checkpoint: test loss = 0.4104 <---------------
# ---------- Epoch 123 ----------
# loss: 0.2068, test loss: 0.4102
# Checkpoint: test loss = 0.4102 <---------------
# ---------- Epoch 124 ----------
# loss: 0.1962, test loss: 0.4100
# Checkpoint: test loss = 0.4100 <---------------
# ---------- Epoch 125 ----------
# loss: 0.2006, test loss: 0.4099
# Checkpoint: test loss = 0.4099 <---------------
# ---------- Epoch 126 ----------
# loss: 0.2058, test loss: 0.4097
# Checkpoint: test loss = 0.4097 <---------------
# ---------- Epoch 127 ----------
# loss: 0.2082, test loss: 0.4095
# Checkpoint: test loss = 0.4095 <---------------
# ---------- Epoch 128 ----------
# loss: 0.2093, test loss: 0.4093
# Checkpoint: test loss = 0.4093 <---------------
# ---------- Epoch 129 ----------
# loss: 0.2021, test loss: 0.4091
# Checkpoint: test loss = 0.4091 <---------------
# ---------- Epoch 130 ----------
# loss: 0.2094, test loss: 0.4089
# Checkpoint: test loss = 0.4089 <---------------
# ---------- Epoch 131 ----------
# loss: 0.2021, test loss: 0.4087
# Checkpoint: test loss = 0.4087 <---------------
# ---------- Epoch 132 ----------
# loss: 0.2043, test loss: 0.4085
# Checkpoint: test loss = 0.4085 <---------------
# ---------- Epoch 133 ----------
# loss: 0.1978, test loss: 0.4084
# Checkpoint: test loss = 0.4084 <---------------
# ---------- Epoch 134 ----------
# loss: 0.2111, test loss: 0.4082
# Checkpoint: test loss = 0.4082 <---------------
# ---------- Epoch 135 ----------
# loss: 0.2018, test loss: 0.4080
# Checkpoint: test loss = 0.4080 <---------------
# ---------- Epoch 136 ----------
# loss: 0.2039, test loss: 0.4078
# Checkpoint: test loss = 0.4078 <---------------
# ---------- Epoch 137 ----------
# loss: 0.1996, test loss: 0.4076
# Checkpoint: test loss = 0.4076 <---------------
# ---------- Epoch 138 ----------
# loss: 0.2057, test loss: 0.4074
# Checkpoint: test loss = 0.4074 <---------------
# ---------- Epoch 139 ----------
# loss: 0.2047, test loss: 0.4072
# Checkpoint: test loss = 0.4072 <---------------
# ---------- Epoch 140 ----------
# loss: 0.2031, test loss: 0.4070
# Checkpoint: test loss = 0.4070 <---------------
# ---------- Epoch 141 ----------
# loss: 0.2028, test loss: 0.4068
# Checkpoint: test loss = 0.4068 <---------------
# ---------- Epoch 142 ----------
# loss: 0.2007, test loss: 0.4066
# Checkpoint: test loss = 0.4066 <---------------
# ---------- Epoch 143 ----------
# loss: 0.2035, test loss: 0.4064
# Checkpoint: test loss = 0.4064 <---------------
# ---------- Epoch 144 ----------
# loss: 0.1971, test loss: 0.4062
# Checkpoint: test loss = 0.4062 <---------------
# ---------- Epoch 145 ----------
# loss: 0.2002, test loss: 0.4061
# Checkpoint: test loss = 0.4061 <---------------
# ---------- Epoch 146 ----------
# loss: 0.1970, test loss: 0.4059
# Checkpoint: test loss = 0.4059 <---------------
# ---------- Epoch 147 ----------
# loss: 0.2068, test loss: 0.4057
# Checkpoint: test loss = 0.4057 <---------------
# ---------- Epoch 148 ----------
# loss: 0.1997, test loss: 0.4055
# Checkpoint: test loss = 0.4055 <---------------
# ---------- Epoch 149 ----------
# loss: 0.1986, test loss: 0.4053
# Checkpoint: test loss = 0.4053 <---------------
# ---------- Epoch 150 ----------
# loss: 0.1978, test loss: 0.4051
# Checkpoint: test loss = 0.4051 <---------------
# ---------- Epoch 151 ----------
# loss: 0.2006, test loss: 0.4049
# Checkpoint: test loss = 0.4049 <---------------
# ---------- Epoch 152 ----------
# loss: 0.1975, test loss: 0.4047
# Checkpoint: test loss = 0.4047 <---------------
# ---------- Epoch 153 ----------
# loss: 0.1971, test loss: 0.4045
# Checkpoint: test loss = 0.4045 <---------------
# ---------- Epoch 154 ----------
# loss: 0.1988, test loss: 0.4043
# Checkpoint: test loss = 0.4043 <---------------
# ---------- Epoch 155 ----------
# loss: 0.2003, test loss: 0.4041
# Checkpoint: test loss = 0.4041 <---------------
# ---------- Epoch 156 ----------
# loss: 0.1868, test loss: 0.4039
# Checkpoint: test loss = 0.4039 <---------------
# ---------- Epoch 157 ----------
# loss: 0.2028, test loss: 0.4037
# Checkpoint: test loss = 0.4037 <---------------
# ---------- Epoch 158 ----------
# loss: 0.1951, test loss: 0.4035
# Checkpoint: test loss = 0.4035 <---------------
# ---------- Epoch 159 ----------
# loss: 0.1895, test loss: 0.4033
# Checkpoint: test loss = 0.4033 <---------------
# ---------- Epoch 160 ----------
# loss: 0.1938, test loss: 0.4032
# Checkpoint: test loss = 0.4032 <---------------
# ---------- Epoch 161 ----------
# loss: 0.1943, test loss: 0.4030
# Checkpoint: test loss = 0.4030 <---------------
# ---------- Epoch 162 ----------
# loss: 0.1878, test loss: 0.4028
# Checkpoint: test loss = 0.4028 <---------------
# ---------- Epoch 163 ----------
# loss: 0.1961, test loss: 0.4026
# Checkpoint: test loss = 0.4026 <---------------
# ---------- Epoch 164 ----------
# loss: 0.2004, test loss: 0.4024
# Checkpoint: test loss = 0.4024 <---------------
# ---------- Epoch 165 ----------
# loss: 0.1989, test loss: 0.4022
# Checkpoint: test loss = 0.4022 <---------------
# ---------- Epoch 166 ----------
# loss: 0.1961, test loss: 0.4020
# Checkpoint: test loss = 0.4020 <---------------
# ---------- Epoch 167 ----------
# loss: 0.1946, test loss: 0.4017
# Checkpoint: test loss = 0.4017 <---------------
# ---------- Epoch 168 ----------
# loss: 0.2011, test loss: 0.4015
# Checkpoint: test loss = 0.4015 <---------------
# ---------- Epoch 169 ----------
# loss: 0.1886, test loss: 0.4013
# Checkpoint: test loss = 0.4013 <---------------
# ---------- Epoch 170 ----------
# loss: 0.1910, test loss: 0.4011
# Checkpoint: test loss = 0.4011 <---------------
# ---------- Epoch 171 ----------
# loss: 0.1967, test loss: 0.4009
# Checkpoint: test loss = 0.4009 <---------------
# ---------- Epoch 172 ----------
# loss: 0.1911, test loss: 0.4007
# Checkpoint: test loss = 0.4007 <---------------
# ---------- Epoch 173 ----------
# loss: 0.1959, test loss: 0.4005
# Checkpoint: test loss = 0.4005 <---------------
# ---------- Epoch 174 ----------
# loss: 0.1940, test loss: 0.4003
# Checkpoint: test loss = 0.4003 <---------------
# ---------- Epoch 175 ----------
# loss: 0.2005, test loss: 0.4002
# Checkpoint: test loss = 0.4002 <---------------
# ---------- Epoch 176 ----------
# loss: 0.1918, test loss: 0.4000
# Checkpoint: test loss = 0.4000 <---------------
# ---------- Epoch 177 ----------
# loss: 0.1945, test loss: 0.3998
# Checkpoint: test loss = 0.3998 <---------------
# ---------- Epoch 178 ----------
# loss: 0.1969, test loss: 0.3996
# Checkpoint: test loss = 0.3996 <---------------
# ---------- Epoch 179 ----------
# loss: 0.1969, test loss: 0.3994
# Checkpoint: test loss = 0.3994 <---------------
# ---------- Epoch 180 ----------
# loss: 0.2005, test loss: 0.3992
# Checkpoint: test loss = 0.3992 <---------------
# ---------- Epoch 181 ----------
# loss: 0.1837, test loss: 0.3990
# Checkpoint: test loss = 0.3990 <---------------
# ---------- Epoch 182 ----------
# loss: 0.1908, test loss: 0.3988
# Checkpoint: test loss = 0.3988 <---------------
# ---------- Epoch 183 ----------
# loss: 0.1908, test loss: 0.3986
# Checkpoint: test loss = 0.3986 <---------------
# ---------- Epoch 184 ----------
# loss: 0.1867, test loss: 0.3984
# Checkpoint: test loss = 0.3984 <---------------
# ---------- Epoch 185 ----------
# loss: 0.1923, test loss: 0.3982
# Checkpoint: test loss = 0.3982 <---------------
# ---------- Epoch 186 ----------
# loss: 0.1874, test loss: 0.3980
# Checkpoint: test loss = 0.3980 <---------------
# ---------- Epoch 187 ----------
# loss: 0.1880, test loss: 0.3978
# Checkpoint: test loss = 0.3978 <---------------
# ---------- Epoch 188 ----------
# loss: 0.1867, test loss: 0.3976
# Checkpoint: test loss = 0.3976 <---------------
# ---------- Epoch 189 ----------
# loss: 0.1836, test loss: 0.3975
# Checkpoint: test loss = 0.3975 <---------------
# ---------- Epoch 190 ----------
# loss: 0.1890, test loss: 0.3973
# Checkpoint: test loss = 0.3973 <---------------
# ---------- Epoch 191 ----------
# loss: 0.1820, test loss: 0.3971
# Checkpoint: test loss = 0.3971 <---------------
# ---------- Epoch 192 ----------
# loss: 0.1882, test loss: 0.3969
# Checkpoint: test loss = 0.3969 <---------------
# ---------- Epoch 193 ----------
# loss: 0.1938, test loss: 0.3967
# Checkpoint: test loss = 0.3967 <---------------
# ---------- Epoch 194 ----------
# loss: 0.1875, test loss: 0.3965
# Checkpoint: test loss = 0.3965 <---------------
# ---------- Epoch 195 ----------
# loss: 0.1935, test loss: 0.3963
# Checkpoint: test loss = 0.3963 <---------------
# ---------- Epoch 196 ----------
# loss: 0.1850, test loss: 0.3961
# Checkpoint: test loss = 0.3961 <---------------
# ---------- Epoch 197 ----------
# loss: 0.1836, test loss: 0.3960
# Checkpoint: test loss = 0.3960 <---------------
# ---------- Epoch 198 ----------
# loss: 0.1856, test loss: 0.3958
# Checkpoint: test loss = 0.3958 <---------------
# ---------- Epoch 199 ----------
# loss: 0.1785, test loss: 0.3956
# Checkpoint: test loss = 0.3956 <---------------
# ---------- Epoch 200 ----------
# loss: 0.1833, test loss: 0.3954
# Checkpoint: test loss = 0.3954 <---------------

# %%
t = period
x_t = x[t - period:t]
x_v = x[t - 1:t]
x_t_flat = torch.concatenate([x_t[:, i] for i in range(x_t.shape[1])])
x_v_flat = torch.concatenate([x_v[:, i] for i in range(x_v.shape[1])])

y_t = y[t - period:t]
y_v = y[t - 1:t]
y_t_flat = torch.concatenate([y_t[:, i] for i in range(y_t.shape[1])])
y_v_flat = torch.concatenate([y_v[:, i] for i in range(y_v.shape[1])])
print(x_t_flat.shape)
# Out:
# torch.Size([7070, 10, 2])

# %%
x_t_flat.shape
# Out:
# torch.Size([7070, 10, 2])
